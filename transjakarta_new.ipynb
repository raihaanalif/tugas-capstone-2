# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('transjakarta_clean.csv')
df.head()
# Out:
#           transID         payCardID payCardBank      payCardName payCardSex  \
# 0  EIIW227B8L34VB   180062659848800      emoney   Bajragin Usada          M
# 1  LGXO740D2N47GZ  4885331907664776         dki     Gandi Widodo          F
# 2  DJWR385V2U57TO  4996225095064169         dki    Emong Wastuti          F
# 3  JTUZ800U7C86EH      639099174703       flazz     Surya Wacana          F
# 4  VMLO535V7F95NJ      570928206772       flazz  Embuh Mardhiyah          M
#
#    payCardBirthDate corridorID                              corridorName  \
# 0              2008          5                     Matraman Baru - Ancol
# 1              1997         6C  Stasiun Tebet - Karet via Patra Kuningan
# 2              1992        R1A                        Pantai Maju - Kota
# 3              1978        11D       Pulo Gebang - Pulo Gadung 2 via PIK
# 4              1982         12                     Tanjung Priok - Pluit
#
# ...

# %% [markdown]
# Coba menghitung kepadatan melalui waktunya

# %%
df['tapInTime'] = pd.to_datetime(df['tapInTime'])
df['tapOutTime'] = pd.to_datetime(df['tapOutTime'])

df['tapInHour'] = df['tapInTime'].dt.hour

plt.figure(figsize=(10, 8))

plt.title('Distribution of Tap In Times by Hour')
sns.histplot(df['tapInHour'], bins=24, kde=False, color='blue')
plt.xlabel('Hour of Day')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Hitung kepadatan berdasarkan koridornya

# %%
corridor_counts = df.groupby('corridorName').size().sort_values(ascending=False)

top_5_corridors = corridor_counts.head(5)

plt.figure(figsize=(10, 6))
sns.barplot(x=top_5_corridors.index, y=top_5_corridors.values, palette='viridis')

plt.title('Number of Passengers by Corridor')
plt.xlabel('Corridor ID')
plt.ylabel('Number of Passengers')

plt.xticks(rotation=45)

plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_30320\4016273507.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_5_corridors.index, y=top_5_corridors.values, palette='viridis')
